# %%
# from google.colab import files
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import os
import numpy as np
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
train = pd.read_csv('/Users/kyongwonkim/Desktop/cherry/train_1011_1.csv')
test = pd.read_csv('/Users/kyongwonkim/Desktop/cherry/test_1011_1.csv')

# %%
train2 = train.copy()
test2 = test.copy()

# %%
print('train2:',train2.shape)
print('test2:',test2.shape)
# Out:
# train2: (10264386, 23)
# test2: (3255482, 23)

# %% [markdown]
# # personal_rehabilitation_yn

# %% [markdown]
# ### train

# %%
#loanapply_insert_time-04-18 13:38:29 이전 NA ->(no response)으로 채우기
#pd.set_option("display.max_columns",None)

train2.loc[(train2['loanapply_insert_time']<"2022-04-18 13:38:29"),'personal_rehabilitation_yn']="no_response"
train2[train2.loanapply_insert_time <"2022-04-18 13:38:29"]
# Out:
#          application_id loanapply_insert_time  bank_id  product_id  \
# 0                566528   2022-03-01 00:11:36       13         123
# 1                180433   2022-03-01 00:12:05       19         231
# 2                180433   2022-03-01 00:12:05       13         262
# 3                180433   2022-03-01 00:12:06       21         196
# 4               1657888   2022-03-01 00:12:06       24         263
# ...                 ...                   ...      ...         ...
# 5263927         1817476   2022-04-18 13:38:05       47          43
# 5263928         1571359   2022-04-18 13:38:06        1          61
# 5263929         2144773   2022-04-18 13:38:11       49         136
# 5263930          669275   2022-04-18 13:38:15       27         176
# 5263931         2121846   2022-04-18 13:38:20       22         164
#
#          loan_limit  loan_rate  is_applied  user_id  birth_year  gender  ...  \
# 0        20000000.0       19.1         0.0   681184      1974.0     1.0  ...
# 1        16000000.0       15.0         0.0   623737      1997.0     1.0  ...
# 2        22000000.0       16.6         0.0   623737      1997.0     1.0  ...
# 3         3000000.0       10.9         1.0   623737      1997.0     1.0  ...
# 4         5000000.0       15.9         0.0   752985      1997.0     1.0  ...
# ...             ...        ...         ...      ...         ...     ...  ...
# 5263927  32000000.0       17.5         0.0   451198      1979.0     0.0  ...
# 5263928  24000000.0       13.9         1.0   631263      1973.0     1.0  ...
# 5263929  10000000.0        6.6         1.0    59819      1993.0     1.0  ...
# 5263930  30000000.0       11.9         0.0   173486      1980.0     1.0  ...
# 5263931  12000000.0        8.0         0.0   274786      1974.0     1.0  ...
#
#              income_type  company_enter_month  employment_type houseown_type  \
# 0            OTHERINCOME                  NaN               기타           전월세
# 1             FREELANCER             202202.0              일용직        기타가족소유
# 2             FREELANCER             202202.0              일용직        기타가족소유
# 3             FREELANCER             202202.0              일용직        기타가족소유
# 4             FREELANCER             202102.0               기타        기타가족소유
# ...                  ...                  ...              ...           ...
# 5263927     EARNEDINCOME             201311.0              정규직        기타가족소유
# 5263928  PRIVATEBUSINESS             201206.0               기타            자가
# 5263929    EARNEDINCOME2             202007.0              정규직        기타가족소유
# 5263930     EARNEDINCOME             201806.0              정규직           전월세
# 5263931    EARNEDINCOME2             201110.0              정규직           전월세
#
#          desired_amount purpose personal_rehabilitation_yn  \
# 0             1000000.0     생활비                no_response
# 1             3000000.0     생활비                no_response
# 2             3000000.0     생활비                no_response
# 3             3000000.0     생활비                no_response
# 4             3000000.0     생활비                no_response
# ...                 ...     ...                        ...
# 5263927      17000000.0    대환대출                no_response
# 5263928      10000000.0     생활비                no_response
# 5263929       3000000.0     생활비                no_response
# 5263930      10000000.0     생활비                no_response
# 5263931      10000000.0    대환대출                no_response
#
#          personal_rehabilitation_complete_yn existing_loan_cnt  \
# 0                                        NaN               4.0
# 1                                        NaN               3.0
# 2                                        NaN               3.0
# 3                                        NaN               3.0
# 4                                        NaN               7.0
# ...                                      ...               ...
# 5263927                                  NaN               3.0
# 5263928                                  NaN               3.0
# 5263929                                  NaN               3.0
# 5263930                                  NaN               NaN
# 5263931                                  NaN               5.0
#
#         existing_loan_amt
# 0              20000000.0
# 1              11000000.0
# 2              11000000.0
# 3              11000000.0
# 4              33000000.0
# ...                   ...
# 5263927        30000000.0
# 5263928       190000000.0
# 5263929        46000000.0
# 5263930               NaN
# 5263931        21000000.0
#
# [5263932 rows x 23 columns]

# %%
#2022-04-18 13:38:29 이후 NA ->(No_response)로 채우기 
train2.loc[(train2['loanapply_insert_time']>="2022-04-18 13:38:29")&(train2['personal_rehabilitation_yn'].isna()),'personal_rehabilitation_yn']="no_response"
train2[train2.loanapply_insert_time >="2022-04-18 13:38:29"]
# Out:
#           application_id loanapply_insert_time  bank_id  product_id  \
# 5263932          1437157   2022-04-18 13:38:30       42         258
# 5263933          1437157   2022-04-18 13:38:30       61          92
# 5263934          1437157   2022-04-18 13:38:30       13         262
# 5263935          1437157   2022-04-18 13:38:30       30         121
# 5263936          1437157   2022-04-18 13:38:30       50         142
# ...                  ...                   ...      ...         ...
# 10264381          455157   2022-05-31 23:54:28       35         168
# 10264382          455157   2022-05-31 23:54:28       55         159
# 10264383          455157   2022-05-31 23:54:29       22         221
# 10264384          455157   2022-05-31 23:54:37       38          16
# 10264385          831190   2022-05-31 23:54:38       52         187
#
#           loan_limit  loan_rate  is_applied  user_id  birth_year  gender  ...  \
# 5263932   38000000.0        9.5         0.0   485729      1995.0     1.0  ...
# 5263933   34000000.0       11.5         0.0   485729      1995.0     1.0  ...
# 5263934   37000000.0       16.1         0.0   485729      1995.0     1.0  ...
# 5263935   15000000.0       13.0         0.0   485729      1995.0     1.0  ...
# 5263936   60000000.0       14.0         0.0   485729      1995.0     1.0  ...
# ...              ...        ...         ...      ...         ...     ...  ...
# 10264381   3000000.0       18.3         0.0   717233      1973.0     1.0  ...
# 10264382   3000000.0       18.9         0.0   717233      1973.0     1.0  ...
# 10264383   5000000.0       18.4         0.0   717233      1973.0     1.0  ...
# 10264384   3000000.0       14.5         0.0   717233      1973.0     1.0  ...
# 10264385   2000000.0        9.5         0.0   472597      1992.0     0.0  ...
#
#               income_type  company_enter_month  employment_type houseown_type  \
# 5263932      EARNEDINCOME             202012.0              정규직            자가
# 5263933      EARNEDINCOME             202012.0              정규직            자가
# 5263934      EARNEDINCOME             202012.0              정규직            자가
# 5263935      EARNEDINCOME             202012.0              정규직            자가
# 5263936      EARNEDINCOME             202012.0              정규직            자가
# ...                   ...                  ...              ...           ...
# 10264381     EARNEDINCOME             199704.0              정규직            자가
# 10264382     EARNEDINCOME             199704.0              정규직            자가
# 10264383     EARNEDINCOME             199704.0              정규직            자가
# 10264384     EARNEDINCOME             199704.0              정규직            자가
# 10264385  PRIVATEBUSINESS             201905.0               기타           전월세
#
#           desired_amount purpose personal_rehabilitation_yn  \
# 5263932       60000000.0     생활비                        0.0
# 5263933       60000000.0     생활비                        0.0
# 5263934       60000000.0     생활비                        0.0
# 5263935       60000000.0     생활비                        0.0
# 5263936       60000000.0     생활비                        0.0
# ...                  ...     ...                        ...
# 10264381      50000000.0    대환대출                        0.0
# 10264382      50000000.0    대환대출                        0.0
# 10264383      50000000.0    대환대출                        0.0
# 10264384      50000000.0    대환대출                        0.0
# 10264385      40000000.0    대환대출                        0.0
#
#           personal_rehabilitation_complete_yn existing_loan_cnt  \
# 5263932                                   0.0               3.0
# 5263933                                   0.0               3.0
# 5263934                                   0.0               3.0
# 5263935                                   0.0               3.0
# 5263936                                   0.0               3.0
# ...                                       ...               ...
# 10264381                                  0.0              12.0
# 10264382                                  0.0              12.0
# 10264383                                  0.0              12.0
# 10264384                                  0.0              12.0
# 10264385                                  0.0               2.0
#
#          existing_loan_amt
# 5263932         74000000.0
# 5263933         74000000.0
# 5263934         74000000.0
# 5263935         74000000.0
# 5263936         74000000.0
# ...                    ...
# 10264381       293000000.0
# 10264382       293000000.0
# 10264383       293000000.0
# 10264384       293000000.0
# 10264385         5000000.0
#
# [5000454 rows x 23 columns]

# %%
train2["personal_rehabilitation_yn"].isna().sum()
# Out:
# 0

# %% [markdown]
# ### test

# %%
test2["personal_rehabilitation_yn"].isna().sum()
# Out:
# 15463

# %%
#test는 모두 2022-04-18 13:38:29 이후 NA ->(No_response)로 채우기 
test2.loc[(test2['personal_rehabilitation_yn'].isna()),'personal_rehabilitation_yn']="no_response"

test2["personal_rehabilitation_yn"].isna().sum()
# Out:
# 0

# %% [markdown]
# # personal_rehabilitation_complete_yn

# %% [markdown]
# ### train

# %%
train2["personal_rehabilitation_complete_yn"].isna().sum()
# Out:
# 9227205

# %%
# personal_rehabilitation 가 0이면(개인회생자 아님) no-rehabilitation

train2.loc[(train2['personal_rehabilitation_yn']==0),'personal_rehabilitation_complete_yn']="no_rehabilitation"
train2.loc[train2['personal_rehabilitation_yn']==0]
# Out:
#           application_id loanapply_insert_time  bank_id  product_id  \
# 5263932          1437157   2022-04-18 13:38:30       42         258
# 5263933          1437157   2022-04-18 13:38:30       61          92
# 5263934          1437157   2022-04-18 13:38:30       13         262
# 5263935          1437157   2022-04-18 13:38:30       30         121
# 5263936          1437157   2022-04-18 13:38:30       50         142
# ...                  ...                   ...      ...         ...
# 10264381          455157   2022-05-31 23:54:28       35         168
# 10264382          455157   2022-05-31 23:54:28       55         159
# 10264383          455157   2022-05-31 23:54:29       22         221
# 10264384          455157   2022-05-31 23:54:37       38          16
# 10264385          831190   2022-05-31 23:54:38       52         187
#
#           loan_limit  loan_rate  is_applied  user_id  birth_year  gender  ...  \
# 5263932   38000000.0        9.5         0.0   485729      1995.0     1.0  ...
# 5263933   34000000.0       11.5         0.0   485729      1995.0     1.0  ...
# 5263934   37000000.0       16.1         0.0   485729      1995.0     1.0  ...
# 5263935   15000000.0       13.0         0.0   485729      1995.0     1.0  ...
# 5263936   60000000.0       14.0         0.0   485729      1995.0     1.0  ...
# ...              ...        ...         ...      ...         ...     ...  ...
# 10264381   3000000.0       18.3         0.0   717233      1973.0     1.0  ...
# 10264382   3000000.0       18.9         0.0   717233      1973.0     1.0  ...
# 10264383   5000000.0       18.4         0.0   717233      1973.0     1.0  ...
# 10264384   3000000.0       14.5         0.0   717233      1973.0     1.0  ...
# 10264385   2000000.0        9.5         0.0   472597      1992.0     0.0  ...
#
#               income_type  company_enter_month  employment_type houseown_type  \
# 5263932      EARNEDINCOME             202012.0              정규직            자가
# 5263933      EARNEDINCOME             202012.0              정규직            자가
# 5263934      EARNEDINCOME             202012.0              정규직            자가
# 5263935      EARNEDINCOME             202012.0              정규직            자가
# 5263936      EARNEDINCOME             202012.0              정규직            자가
# ...                   ...                  ...              ...           ...
# 10264381     EARNEDINCOME             199704.0              정규직            자가
# 10264382     EARNEDINCOME             199704.0              정규직            자가
# 10264383     EARNEDINCOME             199704.0              정규직            자가
# 10264384     EARNEDINCOME             199704.0              정규직            자가
# 10264385  PRIVATEBUSINESS             201905.0               기타           전월세
#
#           desired_amount purpose personal_rehabilitation_yn  \
# 5263932       60000000.0     생활비                        0.0
# 5263933       60000000.0     생활비                        0.0
# 5263934       60000000.0     생활비                        0.0
# 5263935       60000000.0     생활비                        0.0
# 5263936       60000000.0     생활비                        0.0
# ...                  ...     ...                        ...
# 10264381      50000000.0    대환대출                        0.0
# 10264382      50000000.0    대환대출                        0.0
# 10264383      50000000.0    대환대출                        0.0
# 10264384      50000000.0    대환대출                        0.0
# 10264385      40000000.0    대환대출                        0.0
#
#           personal_rehabilitation_complete_yn existing_loan_cnt  \
# 5263932                     no_rehabilitation               3.0
# 5263933                     no_rehabilitation               3.0
# 5263934                     no_rehabilitation               3.0
# 5263935                     no_rehabilitation               3.0
# 5263936                     no_rehabilitation               3.0
# ...                                       ...               ...
# 10264381                    no_rehabilitation              12.0
# 10264382                    no_rehabilitation              12.0
# 10264383                    no_rehabilitation              12.0
# 10264384                    no_rehabilitation              12.0
# 10264385                    no_rehabilitation               2.0
#
#          existing_loan_amt
# 5263932         74000000.0
# 5263933         74000000.0
# 5263934         74000000.0
# 5263935         74000000.0
# 5263936         74000000.0
# ...                    ...
# 10264381       293000000.0
# 10264382       293000000.0
# 10264383       293000000.0
# 10264384       293000000.0
# 10264385         5000000.0
#
# [4370919 rows x 23 columns]

# %%
# personal_rehabilitation 가 no_response -> no_response

train2.loc[(train2['personal_rehabilitation_yn']=="no_response"),'personal_rehabilitation_complete_yn']="no_response"
train2.loc[train2['personal_rehabilitation_yn']=="no_response"]
# Out:
#           application_id loanapply_insert_time  bank_id  product_id  \
# 0                 566528   2022-03-01 00:11:36       13         123
# 1                 180433   2022-03-01 00:12:05       19         231
# 2                 180433   2022-03-01 00:12:05       13         262
# 3                 180433   2022-03-01 00:12:06       21         196
# 4                1657888   2022-03-01 00:12:06       24         263
# ...                  ...                   ...      ...         ...
# 10256217          173189   2022-05-31 21:36:12       62         200
# 10256218          173189   2022-05-31 21:36:14       35          29
# 10256219          173189   2022-05-31 21:36:14       38         223
# 10256220          173189   2022-05-31 21:36:16       22         164
# 10256221          173189   2022-05-31 21:36:25       49         136
#
#           loan_limit  loan_rate  is_applied  user_id  birth_year  gender  ...  \
# 0         20000000.0       19.1         0.0   681184      1974.0     1.0  ...
# 1         16000000.0       15.0         0.0   623737      1997.0     1.0  ...
# 2         22000000.0       16.6         0.0   623737      1997.0     1.0  ...
# 3          3000000.0       10.9         1.0   623737      1997.0     1.0  ...
# 4          5000000.0       15.9         0.0   752985      1997.0     1.0  ...
# ...              ...        ...         ...      ...         ...     ...  ...
# 10256217  11000000.0       14.8         0.0   569416      1968.0     1.0  ...
# 10256218   1000000.0       18.3         0.0   569416      1968.0     1.0  ...
# 10256219  28000000.0       17.3         0.0   569416      1968.0     1.0  ...
# 10256220  15000000.0        8.0         0.0   569416      1968.0     1.0  ...
# 10256221  15000000.0        6.5         1.0   569416      1968.0     1.0  ...
#
#             income_type  company_enter_month  employment_type houseown_type  \
# 0           OTHERINCOME                  NaN               기타           전월세
# 1            FREELANCER             202202.0              일용직        기타가족소유
# 2            FREELANCER             202202.0              일용직        기타가족소유
# 3            FREELANCER             202202.0              일용직        기타가족소유
# 4            FREELANCER             202102.0               기타        기타가족소유
# ...                 ...                  ...              ...           ...
# 10256217  EARNEDINCOME2             201301.0              계약직           전월세
# 10256218  EARNEDINCOME2             201301.0              계약직           전월세
# 10256219  EARNEDINCOME2             201301.0              계약직           전월세
# 10256220  EARNEDINCOME2             201301.0              계약직           전월세
# 10256221  EARNEDINCOME2             201301.0              계약직           전월세
#
#           desired_amount purpose personal_rehabilitation_yn  \
# 0              1000000.0     생활비                no_response
# 1              3000000.0     생활비                no_response
# 2              3000000.0     생활비                no_response
# 3              3000000.0     생활비                no_response
# 4              3000000.0     생활비                no_response
# ...                  ...     ...                        ...
# 10256217      10000000.0     생활비                no_response
# 10256218      10000000.0     생활비                no_response
# 10256219      10000000.0     생활비                no_response
# 10256220      10000000.0     생활비                no_response
# 10256221      10000000.0     생활비                no_response
#
#           personal_rehabilitation_complete_yn existing_loan_cnt  \
# 0                                 no_response               4.0
# 1                                 no_response               3.0
# 2                                 no_response               3.0
# 3                                 no_response               3.0
# 4                                 no_response               7.0
# ...                                       ...               ...
# 10256217                          no_response               NaN
# 10256218                          no_response               NaN
# 10256219                          no_response               NaN
# 10256220                          no_response               NaN
# 10256221                          no_response               NaN
#
#          existing_loan_amt
# 0               20000000.0
# 1               11000000.0
# 2               11000000.0
# 3               11000000.0
# 4               33000000.0
# ...                    ...
# 10256217               NaN
# 10256218               NaN
# 10256219               NaN
# 10256220               NaN
# 10256221               NaN
#
# [5870447 rows x 23 columns]

# %%
# personal_rehabilitation 가 no_response -> no_response
train2.loc[(train2['personal_rehabilitation_yn']=="no_response"),'personal_rehabilitation_complete_yn']="no_response"
train2.loc[train2['personal_rehabilitation_yn']=="no_response"]
# Out:
#           application_id loanapply_insert_time  bank_id  product_id  \
# 0                 566528   2022-03-01 00:11:36       13         123
# 1                 180433   2022-03-01 00:12:05       19         231
# 2                 180433   2022-03-01 00:12:05       13         262
# 3                 180433   2022-03-01 00:12:06       21         196
# 4                1657888   2022-03-01 00:12:06       24         263
# ...                  ...                   ...      ...         ...
# 10256217          173189   2022-05-31 21:36:12       62         200
# 10256218          173189   2022-05-31 21:36:14       35          29
# 10256219          173189   2022-05-31 21:36:14       38         223
# 10256220          173189   2022-05-31 21:36:16       22         164
# 10256221          173189   2022-05-31 21:36:25       49         136
#
#           loan_limit  loan_rate  is_applied  user_id  birth_year  gender  ...  \
# 0         20000000.0       19.1         0.0   681184      1974.0     1.0  ...
# 1         16000000.0       15.0         0.0   623737      1997.0     1.0  ...
# 2         22000000.0       16.6         0.0   623737      1997.0     1.0  ...
# 3          3000000.0       10.9         1.0   623737      1997.0     1.0  ...
# 4          5000000.0       15.9         0.0   752985      1997.0     1.0  ...
# ...              ...        ...         ...      ...         ...     ...  ...
# 10256217  11000000.0       14.8         0.0   569416      1968.0     1.0  ...
# 10256218   1000000.0       18.3         0.0   569416      1968.0     1.0  ...
# 10256219  28000000.0       17.3         0.0   569416      1968.0     1.0  ...
# 10256220  15000000.0        8.0         0.0   569416      1968.0     1.0  ...
# 10256221  15000000.0        6.5         1.0   569416      1968.0     1.0  ...
#
#             income_type  company_enter_month  employment_type houseown_type  \
# 0           OTHERINCOME                  NaN               기타           전월세
# 1            FREELANCER             202202.0              일용직        기타가족소유
# 2            FREELANCER             202202.0              일용직        기타가족소유
# 3            FREELANCER             202202.0              일용직        기타가족소유
# 4            FREELANCER             202102.0               기타        기타가족소유
# ...                 ...                  ...              ...           ...
# 10256217  EARNEDINCOME2             201301.0              계약직           전월세
# 10256218  EARNEDINCOME2             201301.0              계약직           전월세
# 10256219  EARNEDINCOME2             201301.0              계약직           전월세
# 10256220  EARNEDINCOME2             201301.0              계약직           전월세
# 10256221  EARNEDINCOME2             201301.0              계약직           전월세
#
#           desired_amount purpose personal_rehabilitation_yn  \
# 0              1000000.0     생활비                no_response
# 1              3000000.0     생활비                no_response
# 2              3000000.0     생활비                no_response
# 3              3000000.0     생활비                no_response
# 4              3000000.0     생활비                no_response
# ...                  ...     ...                        ...
# 10256217      10000000.0     생활비                no_response
# 10256218      10000000.0     생활비                no_response
# 10256219      10000000.0     생활비                no_response
# 10256220      10000000.0     생활비                no_response
# 10256221      10000000.0     생활비                no_response
#
#           personal_rehabilitation_complete_yn existing_loan_cnt  \
# 0                                 no_response               4.0
# 1                                 no_response               3.0
# 2                                 no_response               3.0
# 3                                 no_response               3.0
# 4                                 no_response               7.0
# ...                                       ...               ...
# 10256217                          no_response               NaN
# 10256218                          no_response               NaN
# 10256219                          no_response               NaN
# 10256220                          no_response               NaN
# 10256221                          no_response               NaN
#
#          existing_loan_amt
# 0               20000000.0
# 1               11000000.0
# 2               11000000.0
# 3               11000000.0
# 4               33000000.0
# ...                    ...
# 10256217               NaN
# 10256218               NaN
# 10256219               NaN
# 10256220               NaN
# 10256221               NaN
#
# [5870447 rows x 23 columns]

# %%
train2["personal_rehabilitation_complete_yn"].isna().sum()
# Out:
# 0

# %%
train2.personal_rehabilitation_yn.value_counts()
# Out:
# no_response    5870447
# 0.0            4370919
# 1.0              23020
# Name: personal_rehabilitation_yn, dtype: int64

# %%
train2.personal_rehabilitation_complete_yn.value_counts()
# Out:
# no_response          5870447
# no_rehabilitation    4370919
# 0.0                    18926
# 1.0                     4094
# Name: personal_rehabilitation_complete_yn, dtype: int64

# %% [markdown]
# ### test

# %%
test2["personal_rehabilitation_complete_yn"].isna().sum()
# Out:
# 2560283

# %%
test2["personal_rehabilitation_complete_yn"].value_counts(dropna=False)
# Out:
# NaN    2560283
# 0.0     692666
# 1.0       2533
# Name: personal_rehabilitation_complete_yn, dtype: int64

# %%
# personal_rehabilitation 가 0이면(개인회생자 아님) no-rehabilitation

test2.loc[(test2['personal_rehabilitation_yn']==0),'personal_rehabilitation_complete_yn']="no_rehabilitation"
test2.loc[test2['personal_rehabilitation_yn']==0]
# Out:
#          application_id loanapply_insert_time  bank_id  product_id  \
# 1                506292   2022-06-01 00:12:24       27         148
# 2                506292   2022-06-01 00:12:24       59         251
# 3                506292   2022-06-01 00:12:24       19         231
# 4                506292   2022-06-01 00:12:25       56           5
# 5                506292   2022-06-01 00:12:34       19         127
# ...                 ...                   ...      ...         ...
# 3255477          634459   2022-06-30 23:54:48       19         231
# 3255478          634459   2022-06-30 23:54:48       10         149
# 3255479          634459   2022-06-30 23:54:48       10          65
# 3255480         1288711   2022-06-30 23:54:52       35         267
# 3255481         1288711   2022-06-30 23:55:00       27         176
#
#          loan_limit  loan_rate  is_applied  user_id  birth_year  gender  ...  \
# 1        13000000.0        7.2         NaN   669202      1981.0     1.0  ...
# 2        11000000.0        6.8         NaN   669202      1981.0     1.0  ...
# 3        24000000.0       15.6         NaN   669202      1981.0     1.0  ...
# 4         2000000.0       18.5         NaN   669202      1981.0     1.0  ...
# 5        13000000.0        9.5         NaN   669202      1981.0     1.0  ...
# ...             ...        ...         ...      ...         ...     ...  ...
# 3255477  11000000.0       16.6         NaN   244440      2000.0     1.0  ...
# 3255478  30000000.0       14.5         NaN   244440      2000.0     1.0  ...
# 3255479  30000000.0       14.5         NaN   244440      2000.0     1.0  ...
# 3255480   3000000.0       13.8         NaN   450880      1976.0     0.0  ...
# 3255481  21000000.0       12.8         NaN   450880      1976.0     0.0  ...
#
#           income_type  company_enter_month  employment_type houseown_type  \
# 1        EARNEDINCOME             202201.0              정규직        기타가족소유
# 2        EARNEDINCOME             202201.0              정규직        기타가족소유
# 3        EARNEDINCOME             202201.0              정규직        기타가족소유
# 4        EARNEDINCOME             202201.0              정규직        기타가족소유
# 5        EARNEDINCOME             202201.0              정규직        기타가족소유
# ...               ...                  ...              ...           ...
# 3255477  PRACTITIONER           20220501.0              정규직        기타가족소유
# 3255478  PRACTITIONER           20220501.0              정규직        기타가족소유
# 3255479  PRACTITIONER           20220501.0              정규직        기타가족소유
# 3255480  PRACTITIONER           20010501.0              정규직            자가
# 3255481  PRACTITIONER           20010501.0              정규직            자가
#
#          desired_amount purpose personal_rehabilitation_yn  \
# 1            16000000.0     생활비                        0.0
# 2            16000000.0     생활비                        0.0
# 3            16000000.0     생활비                        0.0
# 4            16000000.0     생활비                        0.0
# 5            16000000.0     생활비                        0.0
# ...                 ...     ...                        ...
# 3255477       5000000.0     생활비                        0.0
# 3255478       5000000.0     생활비                        0.0
# 3255479       5000000.0     생활비                        0.0
# 3255480      50000000.0    대환대출                        0.0
# 3255481      50000000.0    대환대출                        0.0
#
#          personal_rehabilitation_complete_yn existing_loan_cnt  \
# 1                          no_rehabilitation               1.0
# 2                          no_rehabilitation               1.0
# 3                          no_rehabilitation               1.0
# 4                          no_rehabilitation               1.0
# 5                          no_rehabilitation               1.0
# ...                                      ...               ...
# 3255477                    no_rehabilitation               1.0
# 3255478                    no_rehabilitation               1.0
# 3255479                    no_rehabilitation               1.0
# 3255480                    no_rehabilitation               NaN
# 3255481                    no_rehabilitation               NaN
#
#         existing_loan_amt
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# 5                     NaN
# ...                   ...
# 3255477               NaN
# 3255478               NaN
# 3255479               NaN
# 3255480               NaN
# 3255481               NaN
#
# [3221862 rows x 23 columns]

# %%
# personal_rehabilitation 가 no_response -> no_response
test2.loc[(test2['personal_rehabilitation_yn']=="no_response"),'personal_rehabilitation_complete_yn']="no_response"
test2.loc[test2['personal_rehabilitation_yn']=="no_response"]
# Out:
#          application_id loanapply_insert_time  bank_id  product_id  \
# 1098             179316   2022-06-01 00:40:35       55          25
# 1099             179316   2022-06-01 00:40:35       29         265
# 1104             179316   2022-06-01 00:40:35       42         249
# 1107             179316   2022-06-01 00:40:35       35          29
# 1110             179316   2022-06-01 00:40:35       13         262
# ...                 ...                   ...      ...         ...
# 3246475          526892   2022-06-30 21:18:41       27         176
# 3246477          526892   2022-06-30 21:18:47       29          75
# 3246478          526892   2022-06-30 21:18:48       22         164
# 3246479          526892   2022-06-30 21:18:48       22         100
# 3246480          526892   2022-06-30 21:18:50        8          31
#
#          loan_limit  loan_rate  is_applied  user_id  birth_year  gender  ...  \
# 1098     26000000.0       14.5         NaN   519250      1991.0     1.0  ...
# 1099     28000000.0        8.1         NaN   519250      1991.0     1.0  ...
# 1104      7000000.0        9.6         NaN   519250      1991.0     1.0  ...
# 1107      5000000.0       14.5         NaN   519250      1991.0     1.0  ...
# 1110     30000000.0       16.4         NaN   519250      1991.0     1.0  ...
# ...             ...        ...         ...      ...         ...     ...  ...
# 3246475  14000000.0       13.7         NaN    46505      1992.0     0.0  ...
# 3246477  21000000.0        8.1         NaN    46505      1992.0     0.0  ...
# 3246478  20000000.0        8.7         NaN    46505      1992.0     0.0  ...
# 3246479   8000000.0       15.3         NaN    46505      1992.0     0.0  ...
# 3246480  23000000.0        7.0         NaN    46505      1992.0     0.0  ...
#
#           income_type  company_enter_month  employment_type houseown_type  \
# 1098       FREELANCER             202110.0               기타        기타가족소유
# 1099       FREELANCER             202110.0               기타        기타가족소유
# 1104       FREELANCER             202110.0               기타        기타가족소유
# 1107       FREELANCER             202110.0               기타        기타가족소유
# 1110       FREELANCER             202110.0               기타        기타가족소유
# ...               ...                  ...              ...           ...
# 3246475  EARNEDINCOME           20201001.0              정규직           전월세
# 3246477  EARNEDINCOME           20201001.0              정규직           전월세
# 3246478  EARNEDINCOME           20201001.0              정규직           전월세
# 3246479  EARNEDINCOME           20201001.0              정규직           전월세
# 3246480  EARNEDINCOME           20201001.0              정규직           전월세
#
#          desired_amount purpose personal_rehabilitation_yn  \
# 1098          3000000.0     생활비                no_response
# 1099          3000000.0     생활비                no_response
# 1104          3000000.0     생활비                no_response
# 1107          3000000.0     생활비                no_response
# 1110          3000000.0     생활비                no_response
# ...                 ...     ...                        ...
# 3246475      10000000.0      투자                no_response
# 3246477      10000000.0      투자                no_response
# 3246478      10000000.0      투자                no_response
# 3246479      10000000.0      투자                no_response
# 3246480      10000000.0      투자                no_response
#
#          personal_rehabilitation_complete_yn existing_loan_cnt  \
# 1098                             no_response               NaN
# 1099                             no_response               NaN
# 1104                             no_response               NaN
# 1107                             no_response               NaN
# 1110                             no_response               NaN
# ...                                      ...               ...
# 3246475                          no_response               NaN
# 3246477                          no_response               NaN
# 3246478                          no_response               NaN
# 3246479                          no_response               NaN
# 3246480                          no_response               NaN
#
#         existing_loan_amt
# 1098                  NaN
# 1099                  NaN
# 1104                  NaN
# 1107                  NaN
# 1110                  NaN
# ...                   ...
# 3246475               NaN
# 3246477               NaN
# 3246478               NaN
# 3246479               NaN
# 3246480               NaN
#
# [15463 rows x 23 columns]

# %%
test2["personal_rehabilitation_complete_yn"].isna().sum()
# Out:
# 0

# %%
test2.personal_rehabilitation_yn.value_counts()
# Out:
# 0.0            3221862
# 1.0              18157
# no_response      15463
# Name: personal_rehabilitation_yn, dtype: int64

# %%
test2.personal_rehabilitation_complete_yn.value_counts()
# Out:
# no_rehabilitation    3221862
# 0.0                    15624
# no_response            15463
# 1.0                     2533
# Name: personal_rehabilitation_complete_yn, dtype: int64

# %% [markdown]
# # birth_year & company_enter_month

# %%
#1011 이상치만 제거

# outlier제거를 위한 변수 만들기
#입사연월에서 연도만 뺀 변수 만들기
train2['company_enter_year']=train2['company_enter_month'].apply(str).str[0:4].apply(float)
train2['company_enter_year']
# Out:
# 0              NaN
# 1           2022.0
# 2           2022.0
# 3           2022.0
# 4           2021.0
#              ...
# 10264381    1997.0
# 10264382    1997.0
# 10264383    1997.0
# 10264384    1997.0
# 10264385    2019.0
# Name: company_enter_year, Length: 10264386, dtype: float64

# %%
train2['age'] = 2022 - train2['birth_year'] +1
train2['working_year'] = 2022 - train2['company_enter_year']+1


train2.loc[(train2['age']-train2['working_year'])<=0] #태어나기도 전에 일한사람? 731 rows
# Out:
#          application_id loanapply_insert_time  bank_id  product_id  \
# 983678           706921   2022-03-10 12:59:58       18         188
# 983679           706921   2022-03-10 12:59:58       52         234
# 983680           706921   2022-03-10 12:59:58       45         119
# 983699           706921   2022-03-10 13:00:00       25         169
# 983700           706921   2022-03-10 13:00:00       34          40
# ...                 ...                   ...      ...         ...
# 9963815           83162   2022-05-29 09:08:28       29         265
# 9963816           83162   2022-05-29 09:08:28       14         128
# 9963817           83162   2022-05-29 09:08:28       42         258
# 9963818           83162   2022-05-29 09:08:28        1          61
# 9963819           83162   2022-05-29 09:08:28        3         205
#
#           loan_limit  loan_rate  is_applied  user_id  birth_year  gender  ...  \
# 983678   100000000.0        6.3         0.0   505707      1997.0     1.0  ...
# 983679    50000000.0        4.6         0.0   505707      1997.0     1.0  ...
# 983680    66000000.0        4.3         0.0   505707      1997.0     1.0  ...
# 983699    25000000.0       18.9         0.0   505707      1997.0     1.0  ...
# 983700    50000000.0       18.9         0.0   505707      1997.0     1.0  ...
# ...              ...        ...         ...      ...         ...     ...  ...
# 9963815   34000000.0        9.0         0.0   313726      1995.0     1.0  ...
# 9963816    8000000.0       17.9         0.0   313726      1995.0     1.0  ...
# 9963817   38000000.0       13.1         0.0   313726      1995.0     1.0  ...
# 9963818   69000000.0       12.4         0.0   313726      1995.0     1.0  ...
# 9963819   10000000.0       18.9         0.0   313726      1995.0     1.0  ...
#
#         houseown_type  desired_amount  purpose personal_rehabilitation_yn  \
# 983678            전월세      16000000.0      생활비                no_response
# 983679            전월세      16000000.0      생활비                no_response
# 983680            전월세      16000000.0      생활비                no_response
# 983699            전월세      16000000.0      생활비                no_response
# 983700            전월세      16000000.0      생활비                no_response
# ...               ...             ...      ...                        ...
# 9963815            자가     200000000.0     주택구입                        0.0
# 9963816            자가     200000000.0     주택구입                        0.0
# 9963817            자가     200000000.0     주택구입                        0.0
# 9963818            자가     200000000.0     주택구입                        0.0
# 9963819            자가     200000000.0     주택구입                        0.0
#
#          personal_rehabilitation_complete_yn existing_loan_cnt  \
# 983678                           no_response               NaN
# 983679                           no_response               NaN
# 983680                           no_response               NaN
# 983699                           no_response               NaN
# 983700                           no_response               NaN
# ...                                      ...               ...
# 9963815                    no_rehabilitation               NaN
# 9963816                    no_rehabilitation               NaN
# 9963817                    no_rehabilitation               NaN
# 9963818                    no_rehabilitation               NaN
# 9963819                    no_rehabilitation               NaN
#
#         existing_loan_amt  company_enter_year   age working_year
# 983678                NaN              1997.0  26.0         26.0
# 983679                NaN              1997.0  26.0         26.0
# 983680                NaN              1997.0  26.0         26.0
# 983699                NaN              1997.0  26.0         26.0
# 983700                NaN              1997.0  26.0         26.0
# ...                   ...                 ...   ...          ...
# 9963815               NaN              1990.0  28.0         33.0
# 9963816               NaN              1990.0  28.0         33.0
# 9963817               NaN              1990.0  28.0         33.0
# 9963818               NaN              1990.0  28.0         33.0
# 9963819               NaN              1990.0  28.0         33.0
#
# [731 rows x 26 columns]

# %%
#나이가 근속기간보다 많으면 company_enter_month  NA 처리  

#ujic.loc[(ujic['age']-ujic['working_year'])<=0, "birth_year"]=np.nan
train2.loc[(train2['age']-train2['working_year'])<=0, "company_enter_month"]=np.nan

del train2['working_year']
del train2['age']

# %%
test2['company_enter_year']=test2['company_enter_month'].apply(str).str[0:4].apply(float)

test2['age'] = 2022 - test2['birth_year'] +1
test2['working_year'] = 2022 - test2['company_enter_year']+1

test2.loc[(test2['age']-test2['working_year'])<=0, "company_enter_month"]=np.nan

del test2['working_year']
del test2['age']

# %%
train2.loc[train2["company_enter_month"]<197000.0]
# Out:
#          application_id loanapply_insert_time  bank_id  product_id  \
# 1616502         1769164   2022-03-16 10:58:47       45         119
# 1616504         1769164   2022-03-16 10:58:47       35          29
# 1616505         1769164   2022-03-16 10:58:47       44           8
# 1616506         1769164   2022-03-16 10:58:47       13         262
# 1616509         1769164   2022-03-16 10:58:47       57          71
# 1616510         1769164   2022-03-16 10:58:47       55          12
# 1616511         1769164   2022-03-16 10:58:47       42         258
# 1616512         1769164   2022-03-16 10:58:47       29         265
# 1616515         1769164   2022-03-16 10:58:47       30         121
# 1616523         1769164   2022-03-16 10:58:48        3         152
# 1616530         1769164   2022-03-16 10:58:48        1           1
# 1616533         1769164   2022-03-16 10:58:48       14         197
# 1616534         1769164   2022-03-16 10:58:48       32          56
# 1616536         1769164   2022-03-16 10:58:49       21          30
# 1616556         1769164   2022-03-16 10:58:54       19          26
# 1616597         1769164   2022-03-16 10:59:10       29          20
# 1616602         1769164   2022-03-16 10:59:11       20         111
# 1619783          993197   2022-03-16 11:16:43       30         121
# 1619784          993197   2022-03-16 11:16:43       59         150
# 1619786          993197   2022-03-16 11:16:44       57          71
# 1619787          993197   2022-03-16 11:16:44       13         262
# 1619788          993197   2022-03-16 11:16:44       35          29
# 1619789          993197   2022-03-16 11:16:44       14         197
# 1619790          993197   2022-03-16 11:16:44       29         265
# 1619791          993197   2022-03-16 11:16:44        1           1
# 1619792          993197   2022-03-16 11:16:44       55          12
# 1619793          993197   2022-03-16 11:16:44       44           8
# 1619794          993197   2022-03-16 11:16:44       43         246
# 1619795          993197   2022-03-16 11:16:44       42         258
# 1619796          993197   2022-03-16 11:16:45       36          60
# 1619797          993197   2022-03-16 11:16:45        3         152
# 1619798          993197   2022-03-16 11:16:45       34         215
# 1619799          993197   2022-03-16 11:16:45       32          56
# 1619800          993197   2022-03-16 11:16:45       25         163
# 1619801          993197   2022-03-16 11:16:45       26          80
# 1619813          993197   2022-03-16 11:16:50       19          26
# 1619879          993197   2022-03-16 11:17:02       20         111
#
#          loan_limit  loan_rate  is_applied  user_id  birth_year  gender  ...  \
# 1616502   4000000.0        3.2         0.0   284238         NaN     NaN  ...
# 1616504   5000000.0       15.5         0.0   284238         NaN     NaN  ...
# 1616505   5000000.0       14.6         0.0   284238         NaN     NaN  ...
# 1616506  50000000.0       13.4         0.0   284238         NaN     NaN  ...
# 1616509  50000000.0       10.2         0.0   284238         NaN     NaN  ...
# 1616510  50000000.0       11.1         0.0   284238         NaN     NaN  ...
# 1616511  44000000.0        9.5         0.0   284238         NaN     NaN  ...
# 1616512  34000000.0        7.0         0.0   284238         NaN     NaN  ...
# 1616515  50000000.0       12.5         0.0   284238         NaN     NaN  ...
# 1616523  30000000.0        9.9         0.0   284238         NaN     NaN  ...
# 1616530  60000000.0        8.9         0.0   284238         NaN     NaN  ...
# 1616533  10000000.0        9.8         0.0   284238         NaN     NaN  ...
# 1616534  15000000.0       13.4         0.0   284238         NaN     NaN  ...
# 1616536  13000000.0        8.9         0.0   284238         NaN     NaN  ...
# 1616556  50000000.0       13.6         0.0   284238         NaN     NaN  ...
# 1616597  50000000.0        7.2         0.0   284238         NaN     NaN  ...
# 1616602  22000000.0        7.0         0.0   284238         NaN     NaN  ...
# 1619783  50000000.0       12.5         0.0   284238         NaN     NaN  ...
# 1619784   5000000.0       12.8         0.0   284238         NaN     NaN  ...
# 1619786  50000000.0       10.2         0.0   284238         NaN     NaN  ...
# 1619787  50000000.0       13.4         0.0   284238         NaN     NaN  ...
# 1619788   5000000.0       15.5         0.0   284238         NaN     NaN  ...
# 1619789  10000000.0        9.8         0.0   284238         NaN     NaN  ...
# 1619790  34000000.0        7.0         0.0   284238         NaN     NaN  ...
# 1619791  60000000.0        8.9         0.0   284238         NaN     NaN  ...
# 1619792  50000000.0       11.1         0.0   284238         NaN     NaN  ...
# 1619793   5000000.0       14.6         0.0   284238         NaN     NaN  ...
# 1619794  40000000.0       14.8         0.0   284238         NaN     NaN  ...
# 1619795  44000000.0        9.5         0.0   284238         NaN     NaN  ...
# 1619796  60000000.0       10.4         0.0   284238         NaN     NaN  ...
# 1619797  30000000.0        9.9         0.0   284238         NaN     NaN  ...
# 1619798  50000000.0       11.9         0.0   284238         NaN     NaN  ...
# 1619799  15000000.0       13.4         0.0   284238         NaN     NaN  ...
# 1619800  50000000.0        6.9         0.0   284238         NaN     NaN  ...
# 1619801  50000000.0       11.9         0.0   284238         NaN     NaN  ...
# 1619813  47000000.0       13.6         0.0   284238         NaN     NaN  ...
# 1619879  22000000.0        7.0         0.0   284238         NaN     NaN  ...
#
#         company_enter_month  employment_type  houseown_type desired_amount  \
# 1616502            194201.0              정규직             자가   1.000000e+10
# 1616504            194201.0              정규직             자가   1.000000e+10
# 1616505            194201.0              정규직             자가   1.000000e+10
# 1616506            194201.0              정규직             자가   1.000000e+10
# 1616509            194201.0              정규직             자가   1.000000e+10
# 1616510            194201.0              정규직             자가   1.000000e+10
# 1616511            194201.0              정규직             자가   1.000000e+10
# 1616512            194201.0              정규직             자가   1.000000e+10
# 1616515            194201.0              정규직             자가   1.000000e+10
# 1616523            194201.0              정규직             자가   1.000000e+10
# 1616530            194201.0              정규직             자가   1.000000e+10
# 1616533            194201.0              정규직             자가   1.000000e+10
# 1616534            194201.0              정규직             자가   1.000000e+10
# 1616536            194201.0              정규직             자가   1.000000e+10
# 1616556            194201.0              정규직             자가   1.000000e+10
# 1616597            194201.0              정규직             자가   1.000000e+10
# 1616602            194201.0              정규직             자가   1.000000e+10
# 1619783            194201.0              정규직             자가   1.000000e+06
# 1619784            194201.0              정규직             자가   1.000000e+06
# 1619786            194201.0              정규직             자가   1.000000e+06
# 1619787            194201.0              정규직             자가   1.000000e+06
# 1619788            194201.0              정규직             자가   1.000000e+06
# 1619789            194201.0              정규직             자가   1.000000e+06
# 1619790            194201.0              정규직             자가   1.000000e+06
# 1619791            194201.0              정규직             자가   1.000000e+06
# 1619792            194201.0              정규직             자가   1.000000e+06
# 1619793            194201.0              정규직             자가   1.000000e+06
# 1619794            194201.0              정규직             자가   1.000000e+06
# 1619795            194201.0              정규직             자가   1.000000e+06
# 1619796            194201.0              정규직             자가   1.000000e+06
# 1619797            194201.0              정규직             자가   1.000000e+06
# 1619798            194201.0              정규직             자가   1.000000e+06
# 1619799            194201.0              정규직             자가   1.000000e+06
# 1619800            194201.0              정규직             자가   1.000000e+06
# 1619801            194201.0              정규직             자가   1.000000e+06
# 1619813            194201.0              정규직             자가   1.000000e+06
# 1619879            194201.0              정규직             자가   1.000000e+06
#
#          purpose personal_rehabilitation_yn  \
# 1616502      생활비                no_response
# 1616504      생활비                no_response
# 1616505      생활비                no_response
# 1616506      생활비                no_response
# 1616509      생활비                no_response
# 1616510      생활비                no_response
# 1616511      생활비                no_response
# 1616512      생활비                no_response
# 1616515      생활비                no_response
# 1616523      생활비                no_response
# 1616530      생활비                no_response
# 1616533      생활비                no_response
# 1616534      생활비                no_response
# 1616536      생활비                no_response
# 1616556      생활비                no_response
# 1616597      생활비                no_response
# 1616602      생활비                no_response
# 1619783      생활비                no_response
# 1619784      생활비                no_response
# 1619786      생활비                no_response
# 1619787      생활비                no_response
# 1619788      생활비                no_response
# 1619789      생활비                no_response
# 1619790      생활비                no_response
# 1619791      생활비                no_response
# 1619792      생활비                no_response
# 1619793      생활비                no_response
# 1619794      생활비                no_response
# 1619795      생활비                no_response
# 1619796      생활비                no_response
# 1619797      생활비                no_response
# 1619798      생활비                no_response
# 1619799      생활비                no_response
# 1619800      생활비                no_response
# 1619801      생활비                no_response
# 1619813      생활비                no_response
# 1619879      생활비                no_response
#
#         personal_rehabilitation_complete_yn  existing_loan_cnt  \
# 1616502                         no_response                NaN
# 1616504                         no_response                NaN
# 1616505                         no_response                NaN
# 1616506                         no_response                NaN
# 1616509                         no_response                NaN
# 1616510                         no_response                NaN
# 1616511                         no_response                NaN
# 1616512                         no_response                NaN
# 1616515                         no_response                NaN
# 1616523                         no_response                NaN
# 1616530                         no_response                NaN
# 1616533                         no_response                NaN
# 1616534                         no_response                NaN
# 1616536                         no_response                NaN
# 1616556                         no_response                NaN
# 1616597                         no_response                NaN
# 1616602                         no_response                NaN
# 1619783                         no_response                NaN
# 1619784                         no_response                NaN
# 1619786                         no_response                NaN
# 1619787                         no_response                NaN
# 1619788                         no_response                NaN
# 1619789                         no_response                NaN
# 1619790                         no_response                NaN
# 1619791                         no_response                NaN
# 1619792                         no_response                NaN
# 1619793                         no_response                NaN
# 1619794                         no_response                NaN
# 1619795                         no_response                NaN
# 1619796                         no_response                NaN
# 1619797                         no_response                NaN
# 1619798                         no_response                NaN
# 1619799                         no_response                NaN
# 1619800                         no_response                NaN
# 1619801                         no_response                NaN
# 1619813                         no_response                NaN
# 1619879                         no_response                NaN
#
#         existing_loan_amt company_enter_year
# 1616502               NaN             1942.0
# 1616504               NaN             1942.0
# 1616505               NaN             1942.0
# 1616506               NaN             1942.0
# 1616509               NaN             1942.0
# 1616510               NaN             1942.0
# 1616511               NaN             1942.0
# 1616512               NaN             1942.0
# 1616515               NaN             1942.0
# 1616523               NaN             1942.0
# 1616530               NaN             1942.0
# 1616533               NaN             1942.0
# 1616534               NaN             1942.0
# 1616536               NaN             1942.0
# 1616556               NaN             1942.0
# 1616597               NaN             1942.0
# 1616602               NaN             1942.0
# 1619783               NaN             1942.0
# 1619784               NaN             1942.0
# 1619786               NaN             1942.0
# 1619787               NaN             1942.0
# 1619788               NaN             1942.0
# 1619789               NaN             1942.0
# 1619790               NaN             1942.0
# 1619791               NaN             1942.0
# 1619792               NaN             1942.0
# 1619793               NaN             1942.0
# 1619794               NaN             1942.0
# 1619795               NaN             1942.0
# 1619796               NaN             1942.0
# 1619797               NaN             1942.0
# 1619798               NaN             1942.0
# 1619799               NaN             1942.0
# 1619800               NaN             1942.0
# 1619801               NaN             1942.0
# 1619813               NaN             1942.0
# 1619879               NaN             1942.0
#
# [37 rows x 24 columns]

# %%
index1=train2[train2["company_enter_month"]<197000.0].index #application_id : 1769164 - 1942.0년 입사 : 삭제
print(len(index1)) #1명 -> 삭제...
print(train2.shape)
# Out:
# 37
# (10264386, 24)

# %%
train2.drop(index1, inplace=True)
print(train2.shape)
# Out:
# (10264349, 24)

# %%
test2.loc[test2["company_enter_month"]<197000.0]
# Out:
# Empty DataFrame
# Columns: [application_id, loanapply_insert_time, bank_id, product_id, loan_limit, loan_rate, is_applied, user_id, birth_year, gender, insert_time, credit_score, yearly_income, income_type, company_enter_month, employment_type, houseown_type, desired_amount, purpose, personal_rehabilitation_yn, personal_rehabilitation_complete_yn, existing_loan_cnt, existing_loan_amt, company_enter_year]
# Index: []
#
# [0 rows x 24 columns]

# %% [markdown]
# # existing_loan_amt

# %% [markdown]
# ### train

# %%
#기대출건수가 0이면 둘다 0으로 처리

train2.loc[train2['existing_loan_cnt'] ==0, 'existing_loan_amt'] = 0
print(train2.existing_loan_amt.isna().sum())
print(train2.existing_loan_cnt.isna().sum())

print(train2.loc[train2['existing_loan_amt'].isna(), 'existing_loan_cnt'].value_counts())
# Out:
# 3042975
# 2143013
# 1.0    899962
# Name: existing_loan_cnt, dtype: int64

# %%
#existing_loan_amt 대체하기

print(train2['existing_loan_amt'].mean())


train2.loc[train2['existing_loan_amt'] != train2['existing_loan_amt'], 'existing_loan_amt'] = 62990013.37402066

print(train2['existing_loan_amt'].isna().sum())
print(train2['existing_loan_cnt'].isna().sum())
# Out:
# 81687435.86746788
# 0
# 2143013

# %% [markdown]
# ### test

# %%
#기대출건수가 0이면 둘다 0으로 처리

test2.loc[test2['existing_loan_cnt'] ==0, 'existing_loan_amt'] = 0
print(test2.existing_loan_amt.isna().sum())
print(test2.existing_loan_cnt.isna().sum())

print(test2.loc[test2['existing_loan_amt'].isna(), 'existing_loan_cnt'].value_counts())
# Out:
# 845706
# 541673
# 1.0    304033
# Name: existing_loan_cnt, dtype: int64

# %%
#existing_loan_amt 대체하기

test2.loc[test2['existing_loan_amt'] != test2['existing_loan_amt'], 'existing_loan_amt'] = 62990013.37402066

print(test2['existing_loan_amt'].isna().sum())
print(test2['existing_loan_cnt'].isna().sum())
# Out:
# 0
# 541673

# %% [markdown]
# # 한영 통일

# %%
print(train2.purpose.unique())

train2 = train2.replace({"purpose" : "생활비"}, "LIVING") 
train2 = train2.replace({"purpose" : "대환대출"}, "SWITCHLOAN") 
train2 = train2.replace({"purpose" : "사업자금"}, "BUSINESS") 
train2 = train2.replace({"purpose" : "기타"}, "ETC") 
train2 = train2.replace({"purpose" : "자동차구입"}, "BUYCAR") 
train2 = train2.replace({"purpose" : "전월세보증금"}, "HOUSEDEPOSIT") 
train2 = train2.replace({"purpose" : "주택구입"}, "BUYHOUSE") 
train2 = train2.replace({"purpose" : "투자"}, "INVEST") 

print(train2.purpose.unique())
# Out:
# ['생활비' '대환대출' '사업자금' '기타' '자동차구입' '전월세보증금' '주택구입' '투자' 'BUYCAR' 'LIVING'
#  'SWITCHLOAN' 'HOUSEDEPOSIT' 'ETC' 'BUSINESS' 'INVEST' 'BUYHOUSE']
# ['LIVING' 'SWITCHLOAN' 'BUSINESS' 'ETC' 'BUYCAR' 'HOUSEDEPOSIT' 'BUYHOUSE'
#  'INVEST']

# %%
print(test2.purpose.unique())

test2 = test2.replace({"purpose" : "생활비"}, "LIVING") 
test2 = test2.replace({"purpose" : "대환대출"}, "SWITCHLOAN") 
test2 = test2.replace({"purpose" : "사업자금"}, "BUSINESS") 
test2 = test2.replace({"purpose" : "기타"}, "ETC") 
test2 = test2.replace({"purpose" : "자동차구입"}, "BUYCAR") 
test2 = test2.replace({"purpose" : "전월세보증금"}, "HOUSEDEPOSIT") 
test2 = test2.replace({"purpose" : "주택구입"}, "BUYHOUSE") 
test2 = test2.replace({"purpose" : "투자"}, "INVEST") 

print(test2.purpose.unique())
# Out:
# ['생활비' '대환대출' '사업자금' '주택구입' '기타' '전월세보증금' '투자' '자동차구입']
# ['LIVING' 'SWITCHLOAN' 'BUSINESS' 'BUYHOUSE' 'ETC' 'HOUSEDEPOSIT' 'INVEST'
#  'BUYCAR']

# %% [markdown]
# # train: na/notna 분리

# %%
train2.isna().sum()

# %%
#train2 = train2.drop('company_enter_year',axis = 1)
train2_na = train2.loc[(train2['birth_year'].isna()) | (train2['gender'].isna()) | (train2['credit_score'].isna()) | (train2['company_enter_month'].isna()) |(train2['existing_loan_cnt'].isna()) |(train2['company_enter_year'].isna())]
train2_na.isna().sum()

# %%
train2_na.shape

# %%
train2_na.to_csv('/Users/kyongwonkim/Desktop/cherry/train_1011_na.csv',index=False)

# %%
7733096+2531253

# %%
train2_notna = train2.dropna()

# %%
print(train2_notna.isna().sum().sum()

# %%
print(train2_notna.shape)

# %%
train2_notna.to_csv('/Users/kyongwonkim/Desktop/cherry/train_1011_notna.csv',index=False)

# %% [markdown]
# # test: na/notna

# %% [markdown]
# test_na 만들기

# %%
test2.isna().sum()
# Out:
# application_id                               0
# loanapply_insert_time                        0
# bank_id                                      0
# product_id                                   0
# loan_limit                                   0
# loan_rate                                    0
# is_applied                             3255482
# user_id                                      0
# birth_year                               30815
# gender                                   30815
# insert_time                                  0
# credit_score                            265321
# yearly_income                                6
# income_type                                  0
# company_enter_month                      80836
# employment_type                              0
# houseown_type                                0
# desired_amount                               0
# purpose                                      0
# personal_rehabilitation_yn                   0
# personal_rehabilitation_complete_yn          0
# existing_loan_cnt                       541673
# existing_loan_amt                            0
# company_enter_year                       80112
# dtype: int64

# %%
print(test2.shape)
# Out:
# (3255482, 24)

# %%
#test2 = test2.drop('company_enter_year',axis=1)
test2_na = test2.loc[ (test2['birth_year'].isna()) | (test2['gender'].isna()) | (test2['credit_score'].isna()) |(test2['yearly_income'].isna()) | (test2['company_enter_month'].isna())| (test2['existing_loan_cnt'].isna())| (test2['company_enter_year'].isna())]
test2_na.isna().sum()
# Out:
# application_id                              0
# loanapply_insert_time                       0
# bank_id                                     0
# product_id                                  0
# loan_limit                                  0
# loan_rate                                   0
# is_applied                             652345
# user_id                                     0
# birth_year                              30815
# gender                                  30815
# insert_time                                 0
# credit_score                           265321
# yearly_income                               6
# income_type                                 0
# company_enter_month                     80836
# employment_type                             0
# houseown_type                               0
# desired_amount                              0
# purpose                                     0
# personal_rehabilitation_yn                  0
# personal_rehabilitation_complete_yn         0
# existing_loan_cnt                      541673
# existing_loan_amt                           0
# company_enter_year                      80112
# dtype: int64

# %%
test2_na.shape #(652345, 24)
# Out:
# (652345, 24)

# %%
test2_na.to_csv('/Users/kyongwonkim/Desktop/cherry/test_1011_na.csv',index=False)

# %% [markdown]
# test_notna 만들기

# %%
test_notna =test2.loc[ (test2['birth_year'].notna()) & (test2['gender'].notna()) & (test2['credit_score'].notna()) & (test2['yearly_income'].notna()) & (test2['company_enter_month'].notna())& (test2['existing_loan_cnt'].notna())& (test2['company_enter_year'].notna())]
test_notna.isna().sum()
# Out:
# application_id                               0
# loanapply_insert_time                        0
# bank_id                                      0
# product_id                                   0
# loan_limit                                   0
# loan_rate                                    0
# is_applied                             2603137
# user_id                                      0
# birth_year                                   0
# gender                                       0
# insert_time                                  0
# credit_score                                 0
# yearly_income                                0
# income_type                                  0
# company_enter_month                          0
# employment_type                              0
# houseown_type                                0
# desired_amount                               0
# purpose                                      0
# personal_rehabilitation_yn                   0
# personal_rehabilitation_complete_yn          0
# existing_loan_cnt                            0
# existing_loan_amt                            0
# company_enter_year                           0
# dtype: int64

# %%
test_notna.shape
# Out:
# (2603137, 24)

# %%
2603137+652345
# Out:
# 3255482

# %%
test_notna.to_csv('/Users/kyongwonkim/Desktop/cherry/test_1011_notna.csv',index=False)
